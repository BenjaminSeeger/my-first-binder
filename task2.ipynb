# %% [markdown]
# # Task2 Benjamin Seeger
# In diesem file bearbeite ich die Aufgabe 2 der Vorlesung.
# Da ich im Februar Geburtstag habe, ist mir folgender Fokus zugeteilt:
# Performance – Explainability – Data Analysis

# %%
# Here goes the code for the Task
print("Hello to my task")
# Out:
# Hello to my task
